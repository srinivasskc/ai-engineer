# %% [markdown]
# Chains: using pipelines
#
# Types of Chains
# 1. Simple Chains
# 2. Linear or Sequential Chains
# 3. Conditional Chains
# 4. Parallel Processing Chains

# %% [markdown]
# To visualize the chains, we need to Install grandalf to draw graphs: `pip install grandalf`.
#
# chain.get_graph().print_ascii()

# %% [markdown]
# PromptTemplate is smart enough: when it receives a single plain string input from the previous step, it automatically binds that string to its single variable (text).

# %% [markdown]
# RunnableParallel - This is run the chains in Parallel.
#
# from langchain_core.runnables import RunnableParallel
#
# runnableparallel is type of runnable, with the help of it, we can run multiple chains parallely.
